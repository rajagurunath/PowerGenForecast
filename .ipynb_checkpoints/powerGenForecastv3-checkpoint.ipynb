# %%
# !ls
# Out:
# logs2					model-ep012-loss0.506-val_loss2.474.h5
# model-ep001-loss0.462-val_loss0.761.h5	model-ep013-loss0.587-val_loss4.850.h5
# model-ep001-loss0.466-val_loss0.794.h5	model-ep014-loss0.275-val_loss7.854.h5
# model-ep002-loss0.177-val_loss2.594.h5	model-ep015-loss0.748-val_loss7.901.h5
# model-ep003-loss0.249-val_loss1.439.h5	model-ep016-loss0.459-val_loss6.155.h5
# model-ep004-loss0.163-val_loss1.324.h5	model-ep017-loss0.503-val_loss5.703.h5
# model-ep005-loss0.287-val_loss2.326.h5	model-ep018-loss0.328-val_loss5.385.h5
# model-ep006-loss0.471-val_loss2.425.h5	model-ep019-loss0.488-val_loss6.345.h5
# model-ep007-loss0.506-val_loss1.876.h5	model-ep020-loss0.553-val_loss3.533.h5
# model-ep008-loss0.539-val_loss1.466.h5	model-ep021-loss1.436-val_loss1.000.h5
# model-ep009-loss0.455-val_loss1.955.h5	ngrok
# model-ep010-loss0.260-val_loss1.962.h5	ngrok-stable-linux-amd64.zip
# model-ep011-loss1.250-val_loss1.341.h5	sample_data

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
#import path
import sys

# %%
plt.style.use('seaborn-notebook')

# %%
tf.__version__,pd.__version__
# Out:
# ('1.13.0-rc1', '0.22.0')

# %%
DATA_DIR='https://raw.githubusercontent.com/rajagurunath/PowerGenForecast/master/data/Formatted_data.csv'
electric_df=pd.read_csv(DATA_DIR,sep=';')

# %%
electric_df.head()
# Out:
#            DateTime  Wind Speed  Power Generated  Unnamed: 3
# 0  02-08-2016 00:00     9.80310          86560.0         NaN
# 1  02-08-2016 00:15     9.86182          84960.0         NaN
# 2  02-08-2016 00:30     9.92055          80320.0         NaN
# 3  02-08-2016 00:45     9.57913          77040.0         NaN
# 4  02-08-2016 01:00     9.23771          73760.0         NaN

# %%
electric_df.set_index(pd.to_datetime(electric_df['DateTime']),inplace=True)

# %%
electric_df.iloc[:,:-1].isna().sum()
# Out:
# DateTime              0
# Wind Speed         5088
# Power Generated       0
# dtype: int64

# %% [markdown]
# ## Ploting

# %%
electric_df['Power Generated'].plot(title='Power Generated')
plt.show()

# %%
electric_df['Wind Speed'].plot(title='Wind Speed')
plt.show()

# %% [markdown]
# # Monthwise

# %%
electric_df.resample('1m').sum()['Wind Speed'].plot()

# %%
electric_df.resample('1m').sum()['Power Generated'].plot()

# %% [markdown]
# # Weekly

# %%
electric_df.resample('1w').sum()['Power Generated'].plot()

# %%
electric_df.resample('1w').sum()['Power Generated'].plot()

# %% [markdown]
# # Daywise

# %%
electric_df.resample('1D').sum()['Wind Speed'].plot()

# %%
electric_df.resample('1D').sum()['Power Generated'].plot()

# %% [markdown]
# # Train -test Split

# %%
electric_df['Power Generated'].values.reshape(1,-1)
# Out:
# array([[86560., 84960., 80320., ...,     0.,     0.,     0.]])

# %%
from sklearn.preprocessing import StandardScaler,Normalizer
scalar=StandardScaler()
scaled=scalar.fit_transform(electric_df[['Wind Speed','Power Generated']].values)

electric_df['PowerGenScaled']=scaled[:,0]
electric_df['WindSpeedScaled']=scaled[:,1]

# %%
train=electric_df[:'2018-10']
test=electric_df['2018-10':]
train['Power Generated'].plot(label='train')
test['Power Generated'].plot(label='test')
plt.title('Power Generated')
plt.legend()
plt.show()

# %%
train['PowerGenScaled'].plot(label='train')
test['PowerGenScaled'].plot(label='test')
plt.title('Power Generated scaled')
plt.legend()
plt.show()

# %% [markdown]
# # Neural Networks-Model Building

# %% [markdown]
# ## Approach 1 -Treating power Generated as Sequence

# %%
#@title Train config
INP_SEQ = 96 #@param {type:raw}'

OUT_SEQ=96 #@param {type:raw}'

# %%
power=train['PowerGenScaled'].values
wind=train['WindSpeedScaled'].values

def powerG():
    inp_l=[]
    out_l=[]
    for i in range(power.shape[0]-(OUT_SEQ)):
        yield (wind[i:i+INP_SEQ].reshape(1,-1),power[i:i+OUT_SEQ].reshape(1,-1))
        
def prepare_data(W,P):
    print(W.shape)
    inp_l=[]
    out_l=[]
    for i in range(W.shape[0]-(OUT_SEQ)):
        inp_l.append(W[i:i+INP_SEQ])
        out_l.append(P[i:i+OUT_SEQ])
    X=np.array(inp_l)
    Y=np.array(out_l)
    return X,Y

# %%
X,Y=prepare_data(wind,power)
# Out:
# (77527,)

# %% [markdown]
# ludwigdf=pd.DataFrame({'inp_ts':[X],'out_ts':[Y]},index=range(len(X)))
# ludwigdf.to_csv(DIR+'/ludwig_ts.csv')

# %%
test['Power Generated'][test['Power Generated'].isna()]
test['Power Generated'].plot()

# %%
arraytest=test['PowerGenScaled'].values
powertest=test['PowerGenScaled'].values
windtest=test['WindSpeedScaled'].values


def powerGtest(use_as_iter=True):
    if use_as_iter:
        for i in range(powertest.shape[0]-(OUT_SEQ)):
            yield (windtest[i:i+INP_SEQ].reshape(1,-1),powertest[i:i+OUT_SEQ].reshape(1,-1))
def inference():
    inp_l=[]
    out_l=[]
    for i in range(powertest.shape[0]-(OUT_SEQ)):
        inp_l.append(windtest[i:i+INP_SEQ])
        out_l.append(powertest[i:i+OUT_SEQ])
    X=np.array(inp_l)
    Y=np.array(out_l)
    return X,Y
#xt,yt=powerGtest()

# %%
dstest=tf.data.Dataset.from_generator(powerGtest,(tf.float32,tf.float32),(tf.TensorShape([1,96]),tf.TensorShape([1,96])))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.

# %%
ds=tf.data.Dataset.from_generator(powerG,(tf.float32,tf.float32),(tf.TensorShape([1,96]),tf.TensorShape([1,96])))

# %%
value=ds.make_one_shot_iterator().get_next()
# Out:
# WARNING:tensorflow:From <ipython-input-29-1757bbebbb4a>:1: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.

# %%
sess=tf.Session()
sess.run(value)
# Out:
# (array([[ 0.28185862,  0.25889337,  0.19229412,  0.14521535,  0.09813657,
#           0.11191572,  0.1808115 ,  0.2026285 ,  0.21296285,  0.18425629,
#           0.15095666,  0.13947403,  0.08091263, -0.01554145, -0.16596387,
#          -0.2210805 , -0.11544032, -0.0695098 , -0.08443721, -0.16711214,
#          -0.26930752, -0.30031064, -0.24634227, -0.15562952, -0.14644341,
#          -0.28079015, -0.36116856, -0.43580565, -0.45417786, -0.489774  ,
#          -0.4863292 , -0.4989601 , -0.44843653, -0.3692064 , -0.29227278,
#          -0.22452529, -0.13266425, -0.131516  , -0.07984417, -0.02243103,
#          -0.01554145,  0.08435742,  0.17392191,  0.12454662,  0.04531648,
#           0.00283076, -0.05228586, -0.05343412, -0.06836154,  0.02694428,
#           0.08320916,  0.02349949,  0.05335432,  0.00397902, -0.01324492,
#          -0.09017853, -0.02472755,  0.10272962,  0.07287479,  0.09239525,
#           0.09584004,  0.17162539,  0.02464775,  0.00627555,  0.01890644,
#          -0.04539628,  0.10158136,  0.21870416,  0.2979343 ,  0.40472275,
#           0.5264386 ,  0.54595906,  0.59533435,  0.606817  ,  0.59074134,
#           0.55858994,  0.46213588,  0.46098763,  0.46443242,  0.4552463 ,
#           0.4586911 ,  0.55284864,  0.6251892 ,  0.58729655,  0.50576985,
#           0.43917063,  0.50002855,  0.48969418,  0.5115112 ,  0.48510113,
#           0.4460602 ,  0.3564957 ,  0.2853034 ,  0.22559375,  0.17851497,
#           0.21066633]], dtype=float32),
#  array([[ 1.2200339 ,  1.2423317 ,  1.2646334 ,  1.1349851 ,  1.0053368 ,
#           0.8756885 ,  0.7460439 ,  0.89915216,  1.0522642 ,  1.2053761 ,
#           1.3584844 ,  1.1476985 ,  0.93690896,  0.72611934,  0.5153298 ,
#           0.60300624,  0.6906827 ,  0.7783592 ,  0.7783592 ,  0.8511084 ,
#           0.8361811 ,  0.8212538 ,  0.8063265 ,  0.67070496,  0.5350872 ,
#           0.39946574,  0.2638442 ,  0.3935495 ,  0.52325475,  0.65296006,
#           0.7826654 ,  0.8152312 ,  0.8477971 ,  0.880363  ,  0.9129288 ,
#           0.9602891 ,  1.0076456 ,  1.0550058 ,  1.1023623 ,  1.0977561 ,
#           1.09315   ,  1.0885438 ,  1.0839376 ,  1.1854023 ,  1.286863  ,
#           1.3883314 ,  1.4897959 ,  1.4795432 ,  1.4692904 ,  1.4590375 ,
#           1.4488227 ,  1.462835  ,  1.476847  ,  1.4908592 ,  1.5048714 ,
#           1.486796  ,  1.4687208 ,  1.4506835 ,  1.4326082 ,  1.3148531 ,
#           1.197098  ,  1.0793467 ,  0.9615916 ,  0.96036506,  0.9591385 ,
#           0.9579082 ,  0.95668167,  0.9732494 ,  0.98981714,  1.0063848 ,
#           1.0229526 ,  1.0732292 ,  1.1235058 ,  1.1737825 ,  1.224059  ,
#           1.234308  ,  1.244557  ,  1.2548059 ,  1.265055  ,  1.1090646 ,
#           0.953078  ,  0.7970914 ,  0.6411048 ,  0.6271914 ,  0.6132818 ,
#           0.5993722 ,  0.58546257,  0.5842512 ,  0.5830399 ,  0.58183235,
#           0.580621  ,  0.40635788,  0.23209855,  0.05783543, -0.11642389,
#          -0.00330912]], dtype=float32))

# %%
class windToPower(tf.keras.Model):
    def __init__(self, outseq,num_units=192,batch_size=1):
        super().__init__()
        self.outseq = outseq
        self.batch_size=batch_size
        self.cell = tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell',num_units=num_units)
        self.dense = tf.keras.layers.Dense(units=self.outseq)

    def call(self, inputs):
        state = self.cell.zero_state(batch_size=self.batch_size, dtype=tf.float32)
        output,state=self.cell(inputs,state)
        output=self.dense(output)
        return output

# %%
lstm=windToPower(num_units=INP_SEQ,outseq=OUT_SEQ)
lstm.compile('adam',loss='mse')
# Out:
# WARNING:tensorflow:From <ipython-input-31-68d2c4c075f4>:6: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
TB=tf.keras.callbacks.TensorBoard('./logs2',histogram_freq=10,write_grads=True,batch_size=32,write_graph=True)
ES=tf.keras.callbacks.EarlyStopping(patience=20)
filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'

MC=tf.keras.callbacks.ModelCheckpoint(filepath,save_weights_only=True)
#lstm.load_weights('./lstm2.h5')
history=lstm.fit(ds,epochs=50,steps_per_epoch=500,validation_data=dstest,validation_steps=10,callbacks=[ES,MC,TB])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:1720: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.4691 - val_loss: 0.9228
# Epoch 2/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1818 - val_loss: 2.8897
# Epoch 3/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2318 - val_loss: 2.6181
# Epoch 4/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1644 - val_loss: 1.4459
# Epoch 5/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2790 - val_loss: 2.3488
# Epoch 6/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.4625 - val_loss: 1.6796
# Epoch 7/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4820 - val_loss: 0.6585
# Epoch 8/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.5294 - val_loss: 1.1366
# Epoch 9/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4785 - val_loss: 1.4906
# Epoch 10/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2897 - val_loss: 3.3742
# Epoch 11/50
# 500/500 [==============================] - 1s 3ms/step - loss: 1.1300 - val_loss: 4.7206
# Epoch 12/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.5006 - val_loss: 2.6929
# Epoch 13/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6282 - val_loss: 4.4939
# Epoch 14/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2458 - val_loss: 7.5825
# Epoch 15/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7559 - val_loss: 7.8381
# Epoch 16/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4633 - val_loss: 8.2975
# Epoch 17/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.5023 - val_loss: 5.1160
# Epoch 18/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3193 - val_loss: 4.9321
# Epoch 19/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4978 - val_loss: 5.0394
# Epoch 20/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.5198 - val_loss: 3.6561
# Epoch 21/50
# 500/500 [==============================] - 1s 3ms/step - loss: 1.2698 - val_loss: 1.4564
# Epoch 22/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.8536 - val_loss: 1.4786
# Epoch 23/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.5811 - val_loss: 0.7008
# Epoch 24/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4692 - val_loss: 1.2669
# Epoch 25/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3532 - val_loss: 0.4975
# Epoch 26/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6190 - val_loss: 1.1313
# Epoch 27/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7588 - val_loss: 0.3931
# Epoch 28/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6501 - val_loss: 1.4072
# Epoch 29/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3533 - val_loss: 0.3570
# Epoch 30/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.5217 - val_loss: 0.5229
# Epoch 31/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.5678 - val_loss: 0.3685
# Epoch 32/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3387 - val_loss: 0.2137
# Epoch 33/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2980 - val_loss: 0.5180
# Epoch 34/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4722 - val_loss: 0.2803
# Epoch 35/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3622 - val_loss: 0.4272
# Epoch 36/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6783 - val_loss: 0.3167
# Epoch 37/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.5833 - val_loss: 0.6293
# Epoch 38/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.6576 - val_loss: 0.2187
# Epoch 39/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4610 - val_loss: 0.3402
# Epoch 40/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.3167 - val_loss: 0.2123
# Epoch 41/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.7997 - val_loss: 1.6219
# Epoch 42/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.7518 - val_loss: 0.4530
# Epoch 43/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.5993 - val_loss: 2.0595
# Epoch 44/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.6014 - val_loss: 0.1218
# Epoch 45/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4102 - val_loss: 0.2990
# Epoch 46/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.6026 - val_loss: 0.3237
# Epoch 47/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4999 - val_loss: 1.0154
# Epoch 48/50
# 500/500 [==============================] - 1s 3ms/step - loss: 0.3092 - val_loss: 0.3131
# Epoch 49/50
# 500/500 [==============================] - 1s 2ms/step - loss: 1.9728 - val_loss: 0.6209
# Epoch 50/50
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1925 - val_loss: 0.4155

# %%
# !ls
# Out:
# logs2					model-ep019-loss0.488-val_loss6.345.h5
# model-ep001-loss0.462-val_loss0.761.h5	model-ep019-loss0.498-val_loss5.039.h5
# model-ep001-loss0.466-val_loss0.794.h5	model-ep020-loss0.520-val_loss3.656.h5
# model-ep001-loss0.469-val_loss0.923.h5	model-ep020-loss0.553-val_loss3.533.h5
# model-ep002-loss0.177-val_loss2.594.h5	model-ep021-loss1.270-val_loss1.456.h5
# model-ep002-loss0.182-val_loss2.890.h5	model-ep021-loss1.436-val_loss1.000.h5
# model-ep003-loss0.232-val_loss2.618.h5	model-ep022-loss0.854-val_loss1.479.h5
# model-ep003-loss0.249-val_loss1.439.h5	model-ep023-loss0.581-val_loss0.701.h5
# model-ep004-loss0.163-val_loss1.324.h5	model-ep024-loss0.469-val_loss1.267.h5
# model-ep004-loss0.164-val_loss1.446.h5	model-ep025-loss0.353-val_loss0.497.h5
# model-ep005-loss0.279-val_loss2.349.h5	model-ep026-loss0.619-val_loss1.131.h5
# model-ep005-loss0.287-val_loss2.326.h5	model-ep027-loss0.759-val_loss0.393.h5
# model-ep006-loss0.462-val_loss1.680.h5	model-ep028-loss0.650-val_loss1.407.h5
# model-ep006-loss0.471-val_loss2.425.h5	model-ep029-loss0.353-val_loss0.357.h5
# model-ep007-loss0.482-val_loss0.658.h5	model-ep030-loss0.522-val_loss0.523.h5
# model-ep007-loss0.506-val_loss1.876.h5	model-ep031-loss0.568-val_loss0.369.h5
# model-ep008-loss0.529-val_loss1.137.h5	model-ep032-loss0.339-val_loss0.214.h5
# model-ep008-loss0.539-val_loss1.466.h5	model-ep033-loss0.298-val_loss0.518.h5
# model-ep009-loss0.455-val_loss1.955.h5	model-ep034-loss0.472-val_loss0.280.h5
# model-ep009-loss0.479-val_loss1.491.h5	model-ep035-loss0.362-val_loss0.427.h5
# model-ep010-loss0.260-val_loss1.962.h5	model-ep036-loss0.678-val_loss0.317.h5
# model-ep010-loss0.290-val_loss3.374.h5	model-ep037-loss1.583-val_loss0.629.h5
# model-ep011-loss1.130-val_loss4.721.h5	model-ep038-loss0.658-val_loss0.219.h5
# model-ep011-loss1.250-val_loss1.341.h5	model-ep039-loss0.461-val_loss0.340.h5
# model-ep012-loss0.501-val_loss2.693.h5	model-ep040-loss0.317-val_loss0.212.h5
# model-ep012-loss0.506-val_loss2.474.h5	model-ep041-loss0.800-val_loss1.622.h5
# model-ep013-loss0.587-val_loss4.850.h5	model-ep042-loss0.752-val_loss0.453.h5
# model-ep013-loss0.628-val_loss4.494.h5	model-ep043-loss1.599-val_loss2.059.h5
# model-ep014-loss0.246-val_loss7.583.h5	model-ep044-loss1.601-val_loss0.122.h5
# model-ep014-loss0.275-val_loss7.854.h5	model-ep045-loss0.410-val_loss0.299.h5
# model-ep015-loss0.748-val_loss7.901.h5	model-ep046-loss0.603-val_loss0.324.h5
# model-ep015-loss0.756-val_loss7.838.h5	model-ep047-loss0.500-val_loss1.015.h5
# model-ep016-loss0.459-val_loss6.155.h5	model-ep048-loss0.309-val_loss0.313.h5
# model-ep016-loss0.463-val_loss8.297.h5	model-ep049-loss1.973-val_loss0.621.h5
# model-ep017-loss0.502-val_loss5.116.h5	model-ep050-loss0.193-val_loss0.415.h5
# model-ep017-loss0.503-val_loss5.703.h5	ngrok
# model-ep018-loss0.319-val_loss4.932.h5	ngrok-stable-linux-amd64.zip
# model-ep018-loss0.328-val_loss5.385.h5	sample_data

# %% [markdown]
# # Tensorboard visualization

# %%
LOG_DIR = 'logs2'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip ngrok-stable-linux-amd64.zip
# Out:
# --2019-02-24 13:19:19--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.45.248.161, 52.4.75.11, 52.54.84.112, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.45.248.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5363700 (5.1M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]   5.11M  --.-KB/s    in 0.1s
#
# 2019-02-24 13:19:19 (38.7 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [5363700/5363700]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %% [markdown]
# ***Tensorboard link ***

# %%
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://9a2b9db9.ngrok.io

# %%
plt.plot(lstm.history.history['val_loss'])
plt.title('val loss')
plt.show()

# %%
lstm.evaluate(dstest,steps=100)
# Out:
# 100/100 [==============================] - 0s 868us/step - loss: 2.5436
# 2.543602590560913

# %%
predicted=lstm.predict(dstest,steps=1)

# %%
predicted.shape
# Out:
# (1, 96)

# %% [markdown]
# # inference or prediction time

# %%
test['PowerGenScaled'].plot()

# %%
predicted=lstm.predict_on_batch(dstest)

# %%
testiter=dstest.make_one_shot_iterator()
x,y=testiter.get_next()

# %%
plt.plot(predicted.reshape(-1))
plt.plot(test['PowerGenScaled'].values)
plt.show()

# %%
xtest,ytest=inference()
#lstm.predict(X)

# %%
xtest.shape,ytest.shape,xtest[0].reshape(1,-1).shape
# Out:
# ((31735, 96), (31735, 96), (1, 96))

# %% [markdown]
# # *Prediction for last 10 days*

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
predicted.shape,xtest.shape,predicted.shape,xtest[1].shape
#scalar.inverse_transform([xtest[ithday],predicted[ithday-1]])
# Out:
# ((1, 96), (31735, 96), (1, 96), (96,))

# %%
scalar.inverse_transform(np.array([xtest[1],predicted.reshape(-1)]).reshape(96,-1))
# Out:
# array([[9.58828792e+00, 1.41520000e+05],
#        [8.71136517e+00, 1.03600000e+05],
#        [7.45645847e+00, 8.44000000e+04],
#        [7.14197583e+00, 7.96000000e+04],
#        [7.25083521e+00, 8.68800000e+04],
#        [7.43529137e+00, 9.33600000e+04],
#        [7.87375275e+00, 1.06800000e+05],
#        [8.13985344e+00, 1.07360000e+05],
#        [8.14892506e+00, 1.09840000e+05],
#        [8.19730700e+00, 1.11920000e+05],
#        [8.31523799e+00, 1.09120000e+05],
#        [8.00680310e+00, 9.95200000e+04],
#        [7.66812948e+00, 9.45600000e+04],
#        [7.60765205e+00, 9.69600000e+04],
#        [7.82839467e+00, 1.00320000e+05],
#        [7.88282436e+00, 1.03600000e+05],
#        [8.11566247e+00, 1.07760000e+05],
#        [8.02797020e+00, 9.40800000e+04],
#        [7.14499970e+00, 7.51200000e+04],
#        [6.72468156e+00, 6.68800000e+04],
#        [6.76096802e+00, 7.81600000e+04],
#        [7.11173712e+00, 8.16800000e+04],
#        [7.05428356e+00, 7.48000000e+04],
#        [6.73980091e+00, 6.64800000e+04],
#        [6.23179049e+00, 5.42400000e+04],
#        [6.05942981e+00, 5.71200000e+04],
#        [6.34367374e+00, 6.05600000e+04],
#        [6.45555699e+00, 6.77600000e+04],
#        [6.99380613e+00, 8.48000000e+04],
#        [7.55624623e+00, 8.72000000e+04],
#        [7.29619328e+00, 8.76800000e+04],
#        [7.57438946e+00, 9.76000000e+04],
#        [7.82839467e+00, 9.39200000e+04],
#        [7.54415075e+00, 9.01600000e+04],
#        [7.11778486e+00, 6.75200000e+04],
#        [6.68537123e+00, 7.69600000e+04],
#        [7.46553009e+00, 1.01200000e+05],
#        [8.20033088e+00, 1.19360000e+05],
#        [8.85348713e+00, 1.42720000e+05],
#        [9.73645762e+00, 1.52400000e+05],
#        [9.93603315e+00, 1.57280000e+05],
#        [9.96627186e+00, 1.54160000e+05],
#        [9.77274408e+00, 1.54960000e+05],
#        [9.79995893e+00, 1.50880000e+05],
#        [9.73948150e+00, 1.52000000e+05],
#        [9.78483957e+00, 1.51120000e+05],
#        [9.71226665e+00, 1.50160000e+05],
#        [9.59131179e+00, 1.43520000e+05],
#        [1.01208357e+01, 1.62708684e+05],
#        [1.01690063e+01, 1.63397133e+05],
#        [1.01549281e+01, 1.65282567e+05],
#        [1.02817377e+01, 1.64074244e+05],
#        [1.01510479e+01, 1.57767598e+05],
#        [1.00858146e+01, 1.60893654e+05],
#        [1.03105122e+01, 1.61627683e+05],
#        [1.03335455e+01, 1.69310362e+05],
#        [1.05128363e+01, 1.68747433e+05],
#        [1.03514700e+01, 1.67699337e+05],
#        [1.02755050e+01, 1.58820378e+05],
#        [1.02108581e+01, 1.58582163e+05],
#        [1.02069902e+01, 1.55479137e+05],
#        [1.01286456e+01, 1.58015687e+05],
#        [9.87805202e+00, 1.56026403e+05],
#        [9.76616315e+00, 1.48373315e+05],
#        [9.69091017e+00, 1.48672433e+05],
#        [9.77623778e+00, 1.47872335e+05],
#        [9.60358220e+00, 1.48744889e+05],
#        [9.53999766e+00, 1.54700800e+05],
#        [9.70570629e+00, 1.53837125e+05],
#        [9.81689165e+00, 1.53817939e+05],
#        [9.85940838e+00, 1.55831384e+05],
#        [1.00955305e+01, 1.60279821e+05],
#        [1.02034761e+01, 1.63479572e+05],
#        [1.02409002e+01, 1.63302809e+05],
#        [1.03337317e+01, 1.73383945e+05],
#        [1.07052594e+01, 1.69872088e+05],
#        [1.07177704e+01, 1.74239797e+05],
#        [1.08411818e+01, 1.84437790e+05],
#        [1.11055908e+01, 1.92111142e+05],
#        [1.12339644e+01, 1.90788928e+05],
#        [1.15084983e+01, 1.96852576e+05],
#        [1.14637727e+01, 1.99989031e+05],
#        [1.16368521e+01, 2.00136966e+05],
#        [1.18346164e+01, 2.01946257e+05],
#        [1.18140983e+01, 2.04723663e+05],
#        [1.19448276e+01, 2.08393497e+05],
#        [1.19815536e+01, 2.00924664e+05],
#        [1.18397558e+01, 2.05810262e+05],
#        [1.17219371e+01, 2.00327176e+05],
#        [1.14781259e+01, 1.99008641e+05],
#        [1.13709300e+01, 1.91380046e+05],
#        [1.11940652e+01, 1.92865378e+05],
#        [1.12421759e+01, 1.86883546e+05],
#        [1.10060802e+01, 1.79808910e+05],
#        [1.08506323e+01, 1.81105677e+05],
#        [1.07972681e+01, 1.75426077e+05]])

# %%
for i in range(1,10):
  ithday=len(xtest)-96*i
  predicted=lstm.predict(xtest[ithday].reshape(1,-1))
  original=ytest[ithday]
  
  original=scalar.inverse_transform(np.array([xtest[ithday],original.reshape(-1)]).reshape(OUT_SEQ,-1))[:,1]
  predicted=scalar.inverse_transform(np.array([xtest[ithday],predicted.reshape(-1)]).reshape(OUT_SEQ,-1))[:,1]
  
  plt.plot(predicted.reshape(-1),label='predicted')
  plt.plot(original,label='original')
  mae=mean_absolute_error(original,predicted.reshape(-1))
  rmse=mean_squared_error(original,predicted.reshape(-1))**0.5
  plt.title('Day-{} : mae={} ,rmse={}'.format(i,mae,rmse))
  plt.legend()
  plt.show()

# %%
lstm_est=tf.keras.estimator.model_to_estimator(lstm)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbw3cc587
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:You are creating an Estimator from a Keras model manually subclassed from `Model`, that was already called on some inputs (and thus already had weights). We are currently unable to preserve the model's state (its weights) as part of the estimator in this case. Be warned that the estimator has been created using a freshly initialized version of your model.
# Note that this doesn't affect the state of the model instance you passed as `keras_model` argument.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpbw3cc587', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f61ad6af748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# lstmestimator=tf.keras.estimator.model_to_estimator(keras_model=lstm)
