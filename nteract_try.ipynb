# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
#import path
import sys
# Out:
# F:\anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from vdom import *
from vdom import pre

pd.options.display.html.table_schema = True # Data Explorer On!
pd.options.display.max_rows =1000 # Send all the data! (careful!)

# %%
dfa=pd.read_excel('F:\Electricity_forecast\data\Dataset_A.xlsx')

# %%
dfa
# Out:
#                 Timestamp  Actual_Power Generation [kW]  Wind Speed [m/s]
# 0     2017-09-02 00:00:00                           0.0          5.319590
# 1     2017-09-02 00:15:00                        6966.0          4.848610
# 2     2017-09-02 00:30:00                        4356.0          4.377640
# 3     2017-09-02 00:45:00                       14310.0          4.363380
# 4     2017-09-02 01:00:00                       16380.0          4.349120
# 5     2017-09-02 01:15:00                        6930.0          4.334870
# 6     2017-09-02 01:30:00                        9810.0          4.320610
# 7     2017-09-02 01:45:00                       14004.0          4.056240
# 8     2017-09-02 02:00:00                        9972.0          3.791880
# 9     2017-09-02 02:15:00                        5958.0          3.527510
# 10    2017-09-02 02:30:00                        3924.0          3.263140
# 11    2017-09-02 02:45:00                        6246.0          2.913640
# ...

# %%
dfb=pd.read_excel('F:/Electricity_forecast/data/Dataset_B.xlsx')
dfb.head()
# Out:
#             Timestamp  Actual_Power Generation [kW]  Wind Speed [m/s]
# 0 2017-09-02 00:00:00                        9904.0           4.71047
# 1 2017-09-02 00:15:00                        7084.0           4.21302
# 2 2017-09-02 00:30:00                       10440.0           3.71556
# 3 2017-09-02 00:45:00                        6900.0           3.99065
# 4 2017-09-02 01:00:00                       12730.0           4.26575
